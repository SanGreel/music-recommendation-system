# %%
from __future__ import print_function

# %%
import librosa
import librosa.display
import IPython.display
import numpy as np

# %%
import matplotlib.pyplot as plt
import matplotlib.style as ms
ms.use('seaborn-muted')
# %matplotlib inline

# %%
temp_folder="./data/audio/"

# audio_path = temp_folder+"morricone_full.mp3"
audio_path = temp_folder+"morricone_30s.mp3"
rate = 1

# %%
# Load the example track
y, sr = librosa.load(audio_path)

# %%
# Play it back!
IPython.display.Audio(data=y, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# input audio data array
# otput arrays with diffrent frequencies
def represent_by_freq(audio_data, rate):
    freq = []
    
    return freq

# %%
# input audio frequencies arrays
# otput true if saved
def search_in_DB(freq):
    
    return None

# %%
freq = represent_by_freq(y, rate)
